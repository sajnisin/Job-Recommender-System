# %%
import pandas as pd
import numpy as np
import os
import random

# %%
np.random.seed(42)

# %%
parentdir = os.path.dirname(os.getcwd())
parentdir
# Out:
# 'c:\\Users\\r.quah\\National University of Singapore'

# %%
inputdir = os.path.join(parentdir, r"Nisin Saj - CS5344")
inputdir_data = inputdir + "\Data"
inputdir_data
# Out:
# 'c:\\Users\\r.quah\\National University of Singapore\\Nisin Saj - CS5344\\Data'

# %%
df = pd.read_csv(inputdir_data + "\job_summary.csv", skiprows=lambda x: x > 0 and random.random() >=0.2)
df.head()
# Out:
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/med-surg-re...
# 1  https://www.linkedin.com/jobs/view/store-manag...
# 2  https://www.linkedin.com/jobs/view/senior-rese...
# 3  https://www.linkedin.com/jobs/view/store-manag...
# 4  https://www.linkedin.com/jobs/view/store-manag...
#
#                                          job_summary
# 0  Schedule\n: PRN is required minimum 12 hours p...
# 1  Description\nThe world of working and learning...
# 2  Description\nThe Senior Research Assistant wil...
# 3  Dollar General Corporation has been delivering...
# 4  Description\nAre you a high energy, passionate...

# %%
df.to_csv(inputdir_data + "\job_summary_sample.csv", index=False)
